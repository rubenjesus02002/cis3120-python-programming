# %% [markdown]
# <a href="https://colab.research.google.com/github/rubenjesus02002/cis3120-python-programming-/blob/main/cis_3120_lesson_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Web Scraping with Beautiful Soup**

# %% [markdown]
# **Scraping Wikipedia to Analyze Frequency of Pet Mentions**

# %%
#Searching for elements by id
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Set URL

# %%
url = https://en.wikipedia.org/wiki/Pet
# Out:
# 200

# %%
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Pet - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-featur
# ...

# %% [markdown]
# **"Implements Python's .count() Method to Analyze Pet Mention Frequency"**

# %%
sentence = 'The brown fox jumped over the lazy dog'

# %%
sentence.count('the')
# Out:
# 1

# %%
words = page.text

# %%
pets = ["Cat", "Dog", "Snake", "Fish", "Bird", "Monkey", "Iguana"]

# %%
for pet in pets:
  print(f'Number of {pet} mentions: {words.count(pet)}')
# Out:
# Number of Cat mentions: 214
# Number of Dog mentions: 64
# Number of Snake mentions: 5
# Number of Fish mentions: 6
# Number of Bird mentions: 11
# Number of Monkey mentions: 5
# Number of Iguana mentions: 2

# %%
#Searching for elements by id
import requests
from bs4 import BeautifulSoup

#defining the URL and making a GET request
URL = 'https://avinashjairam.github.io/syllabus.html'
#storing the content returned from the server in an object called page
page = requests.get(URL)

# %%
#importing the HTML returned from the server into beautiful soup
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())

# %%
#finding the <p> with an id of "email"
#you can change the tag 'p' and id to scrape different information on the page
#try scraping the class time, description, etc.!
email_tag = soup.find('p', id='email') # Prints using find rather than find all becasue we only want one output
email_tag

# %%
print(email_tag) #displaying the contents of the emailList

# %%
#Assigning the only value in the list to a variable.
#The get_text() method is used to extract text from an HTML TAG
email = email_tag.get_text()

# %%
#Exporting all items in the email list to a text file
#In this case, only one item is in the file
with open("mailingList.txt", 'w') as out_file:
     for x in email_tag:
        out_file.write(x.get_text())
